# %%
### Data Ingestion

# %%
### document datastructure

from langchain_core.documents import Document

# %%
doc = Document(page_content="This is main tex content to create RAG", 
metadata={"source": "my_source.pdf", "page": 15, "author": "John Doe", "published": "2025-01-01"})

doc
# Out:
# Document(metadata={'source': 'my_source.pdf', 'page': 15, 'author': 'John Doe', 'published': '2025-01-01'}, page_content='This is main tex content to create RAG')

# %%
import os
os.makedirs("../data/rag_data", exist_ok=True)

# %%
### Text Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/rag_data/intro.txt")

doucment = loader.load()
print(doucment)
# Out:
# [Document(metadata={'source': '../data/rag_data/intro.txt'}, page_content='Getting Started with Java\n \n\nElements of a Java Application\nIf you are really, really impatient to run your first Java code, then you can just try the Java Playground available on this site. You can try out almost any snippets of code in it. For example, you can print Hello World!, which is, of course, the first thing you want to try. You don\'t need to install anything, just type some Java code, hit run, and off you go! You can try more of those statements below.\n\n \n Java 25\n+ Preview Features\n1\n// Try changing this message\n2\nIO.println("Welcome to Java programming!");\n3\n\u200b\n4\n// You can print numbers too\n5\nIO.println(42);\n6\n\u200b\n7\n// And even calculations\n8\nIO.println("10 + 5 = " + (10 + 5));\nConsole > \n\u200b\n\nI understand that you are eager to type some code in your editor and run it to see your first Java application in action! Do not worry, your expectation will be fulfil
# ...

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader

loader = DirectoryLoader("../data/rag_data/", glob="**/*.pdf", 
    loader_cls=PyMuPDFLoader, 
    show_progress=False
)

documents = loader.load()
documents
# Out:
# [Document(metadata={'producer': 'Prince 15 (www.princexml.com)', 'creator': '', 'creationdate': '2024-03-15T15:25:16-05:00', 'source': '../data/rag_data/python_intro.pdf', 'file_path': '../data/rag_data/python_intro.pdf', 'total_pages': 415, 'format': 'PDF 1.6', 'title': 'Introduction to Python Programming', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-03-15T15:25:16-05:00', 'trapped': '', 'modDate': "D:20240315152516-05'00'", 'creationDate': "D:20240315152516-05'00'", 'page': 0}, page_content=''),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 2
#       1 import numpy as np
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 import chromadb
#       4 from chromadb.config import Settings
#
# ModuleNotFoundError: No module named 'sentence_transformers'
